# %% [markdown]
# <a href="https://colab.research.google.com/github/razreshili/toy/blob/main/German_run_on_real_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preprocessing and running on real dataset

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.2 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from transformers import pipeline
import pandas as pd

# %% [markdown]
# ## Loading real data from Tobias

# %%
PATH_TO_DATA = "/content/dataset.csv"

# %%
# PATH_TO_DATA = "../datasets/20231109_cleaned_news_data_from_en_sortByDate_2023-09-05_to_2023-11-08.csv"

# %%
df = pd.read_csv(PATH_TO_DATA)

# %%
df.head()
# Out:
#                                             headline         date_publish  \
# 0  SAP-CFO greift durch: "Wir werden jeden Stein ...  2023-11-09 13:09:00
# 1  Haftung bei Unfall in zweispurigem Baustellenb...  2023-10-12 00:00:00
# 2          Ist das alles gewesen, Porsche Automobil?  2023-11-16 20:32:00
# 3  Herando Erfahrungen: Die neuen Cayenne-Modelle...  2023-10-10 08:02:54
# 4  Kartellamt gibt Deal zwischen Porsche und VfB ...  2023-11-03 15:47:11
#
#   language                                        description  \
# 0       de  Europas größter Softwarekonzern SAP hat im dri...
# 1       de  Beim Überholen im zweispurigen Baustellenberei...
# 2       de  Ist das alles gewesen, Porsche Automobil? () |...
# 3       de  Kürzlich präsentierte die Luxusmarke Porsche d...
# 4       de  Der Einstieg von Porsche beim Fußball-Bundesli...
#
#               source_domain  \
# 0      finanznachrichten.de
# 1                  haufe.de
# 2            aktiencheck.de
# 3              prnews24.com
# 4  augsburger-allgemeine.de
#
#                                              article  \
# 0  Europas größter Softwarekonzern SAP hat im dri...
# 1  Bild: Haufe Online Redaktion\n \n \nBeim Überh...
# 2  Für die Aktie Porsche Automobil stehen per 15....
# 3  Prnews24.com\n\n\nKürzlich präsentierte die Lu...
# 4  Der Einstieg von Porsche beim Fußball-Bundesli...
#
#                                                  url   company      rank  \
# 0  https://www.finanznachrichten.de/nachrichten-2...  Infineon    8207.0
# 1  https://www.haufe.de/recht/weitere-rechtsgebie...   Porsche   14831.0
# 2  https://www.aktiencheck.de/news/Artikel-Ist_al...   Porsche  115991.0
# 3  https://www.prnews24.com/403001/herando-erfahr...   Porsche  568988.0
# 4  https://www.augsburger-allgemeine.de/sport/fus...   Porsche    7501.0
#
#                                         api    topic country is_opinion  \
# 0  https://api.newscatcherapi.com/v2/search  finance      DE      False
# 1  https://api.newscatcherapi.com/v2/search     news      DE      False
# 2  https://api.newscatcherapi.com/v2/search     news      DE      False
# 3  https://api.newscatcherapi.com/v2/search     news      DE      False
# 4  https://api.newscatcherapi.com/v2/search     news      DE      False
#
#       _score                                        model_input
# 0  14.040912  Europe's largest software company SAP surprisi...
# 1  14.847401  Things often get tight when overtaking in two-...
# 2  14.850629  Was that all, Porsche Automobile? () | aktienc...
# 3  14.850753  The luxury brand Porsche recently presented th...
# 4  14.973518  Porsche's entry into the Bundesliga soccer clu...

# %%
NEWS_COLUMN = "model_input"

# %%
df[NEWS_COLUMN].head()
# Out:
# 0    Europe's largest software company SAP surprisi...
# 1    Things often get tight when overtaking in two-...
# 2    Was that all, Porsche Automobile? () | aktienc...
# 3    The luxury brand Porsche recently presented th...
# 4    Porsche's entry into the Bundesliga soccer clu...
# Name: model_input, dtype: object

# %%
set(df["language"])
# Out:
# {'de', 'en', nan}

# %% [markdown]
# ### Checking for null values

# %%
sum(df[NEWS_COLUMN].isnull())
# Out:
# 0

# %%
df.dropna(subset=[NEWS_COLUMN], inplace=True)

# %%
len(df)
# Out:
# 46193

# %% [markdown]
# ## Check length of column to use for sentiment analysis

# %%
def check_length(df):
  lengths = df[NEWS_COLUMN].apply(len)
  df_length_of_sentences = pd.DataFrame(list(df[NEWS_COLUMN].apply(len)), columns=[NEWS_COLUMN])
  statistics = df_length_of_sentences.describe()
  print(statistics)
  return df_length_of_sentences

# %%
check_length(df)
# Out:
#         model_input
# count  46193.000000
# mean     354.577035
# std     1006.912212
# min        2.000000
# 25%      104.000000
# 50%      160.000000
# 75%      199.000000
# max    27338.000000
#        model_input
# 0              195
# 1              177
# 2               53
# 3               97
# 4              177
# ...            ...
# 46188         2652
# 46189         2458
# 46190          976
# 46191          791
# 46192          499
#
# [46193 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['model_input'].plot(kind='hist', bins=20, title='model_input')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['model_input'].plot(kind='line', figsize=(8, 4), title='model_input')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Running sentiment prediction

# %%
from transformers import BertForSequenceClassification, BertTokenizer
import torch
import pandas as pd


def load_model(saved_model_path):
    # Load the saved model from the local directory
    model = BertForSequenceClassification.from_pretrained(saved_model_path)
    model.to('cuda')
    # Load the tokenizer if saved separately
    tokenizer = BertTokenizer.from_pretrained(saved_model_path)
    return model, tokenizer

def split_in_chunks(text, tokenizer, chunksize=512):
    """
    Function to split the text in 512 chunks
    :return: the chunks
    """
    # tokenize
    tokens = tokenizer.encode_plus(text, add_special_tokens=False, return_tensors='pt')
    # chunk input ids and mask into chunksize-2 to leave space for 2 tokens for beginning and end: [101], [102]
    input_id_chunks = list(tokens['input_ids'][0].split(chunksize-2))
    mask_chunks = list(tokens['attention_mask'][0].split(chunksize-2))

    for i in range(len(input_id_chunks)):
        # append tokens for beginning of sentence
        input_id_chunks[i] = torch.cat([
            torch.Tensor([101]), input_id_chunks[i], torch.Tensor([102])
        ])
        mask_chunks[i] = torch.cat([
            torch.Tensor([1]), mask_chunks[i], torch.Tensor([1])
        ])

        pad_len = chunksize - input_id_chunks[i].shape[0]
        # adding the padding for "incomplete" sentence
        if pad_len > 0:
            input_id_chunks[i] = torch.cat([
                input_id_chunks[i], torch.Tensor([0] * pad_len)
            ])
            mask_chunks[i] = torch.cat([
                mask_chunks[i], torch.Tensor([0] * pad_len)
            ])
    # put in the right format for the BERT model
    input_ids = torch.stack(input_id_chunks)
    attention_mask = torch.stack(mask_chunks)

    input_dict = {
        'input_ids': input_ids.long(),
        'attention_mask': attention_mask.int()
    }
    return input_dict

def apply_the_model(input_dict, model):
    input_dict = {key: value.to('cuda') for key, value in input_dict.items()}
    model.to('cuda')
    with torch.no_grad():
      outputs = model(**input_dict)
    probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
    mean = probs.mean(dim=0)
    result = torch.argmax(mean).item()
    map_the_label = {'0': "positive", '1': "negative", "2": "neutral"}
    return map_the_label[str(result)]

def analyze_sentiment_batch(texts, model, tokenizer, chunksize=512):
    predictions = []
    for i, text in enumerate(texts):
        input_dict = split_in_chunks(text, tokenizer, chunksize)
        label = apply_the_model(input_dict, model)
        predictions.append({NEWS_COLUMN: text, 'sentiment': label})
    return predictions

# %%
# Load the model and tokenizer
model, tokenizer = load_model("ProsusAI/finbert")


# Specify the batch size
batch_size = 100
# Out:
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
for i in range(0, len(df), batch_size):
    # Extract a batch of texts
    batch_texts = df[NEWS_COLUMN].iloc[i:i + batch_size].tolist()

    # Run sentiment analysis on the batch
    batch_predictions = analyze_sentiment_batch(batch_texts, model, tokenizer, chunksize=512)

    # Save the results (replace 'sentiment_results.csv' with your desired file path)
    results_df = pd.DataFrame(batch_predictions)
    results_df.to_csv('results.csv', mode='a')

    # Print progress
    print(f"Processed {i + len(batch_texts)} rows out of {len(df)}")
# Out:
# Processed 100 rows out of 46193
# Processed 200 rows out of 46193
# Processed 300 rows out of 46193
# Processed 400 rows out of 46193
# Processed 500 rows out of 46193
# Processed 600 rows out of 46193
# Processed 700 rows out of 46193
# Processed 800 rows out of 46193
# Processed 900 rows out of 46193
# Processed 1000 rows out of 46193
# Processed 1100 rows out of 46193
# Processed 1200 rows out of 46193
# Processed 1300 rows out of 46193
# Processed 1400 rows out of 46193
# Processed 1500 rows out of 46193
# Processed 1600 rows out of 46193
# Processed 1700 rows out of 46193
# Processed 1800 rows out of 46193
# Processed 1900 rows out of 46193
# Processed 2000 rows out of 46193
# Processed 2100 rows out of 46193
# Processed 2200 rows out of 46193
# Processed 2300 rows out of 46193
# Processed 2400 rows out of 46193
# Processed 2500 rows out of 46193
# Processed 2600 rows out of 46193
# Processed 2700 rows out of 46193
# Processed 2800 rows out of 46193
# Processed 2900 rows out of 46193
# Processed 3000 rows out of 46193
# Processed 3100 rows out of 46193
# Processed 3200 rows out of 46193
# Processed 3300 rows out of 46193
# Processed 3400 rows out of 46193
# Processed 3500 rows out of 46193
# Processed 3600 rows out of 46193
# Processed 3700 rows out of 46193
# Processed 3800 rows out of 46193
# Processed 3900 rows out of 46193
# Processed 4000 rows out of 46193
# Processed 4100 rows out of 46193
# Processed 4200 rows out of 46193
# Processed 4300 rows out of 46193
# Processed 4400 rows out of 46193
# Processed 4500 rows out of 46193
# Processed 4600 rows out of 46193
# Processed 4700 rows out of 46193
# Processed 4800 rows out of 46193
# Processed 4900 rows out of 46193
# Processed 5000 rows out of 46193
# Processed 5100 rows out of 46193
# Processed 5200 rows out of 46193
# Processed 5300 rows out of 46193
# Processed 5400 rows out of 46193
# Processed 5500 rows out of 46193
# Processed 5600 rows out of 46193
# Processed 5700 rows out of 46193
# Processed 5800 rows out of 46193
# Processed 5900 rows out of 46193
# Processed 6000 rows out of 46193
# Processed 6100 rows out of 46193
# Processed 6200 rows out of 46193
# Processed 6300 rows out of 46193
# Processed 6400 rows out of 46193
# Processed 6500 rows out of 46193
# Processed 6600 rows out of 46193
# Processed 6700 rows out of 46193
# Processed 6800 rows out of 46193
# Processed 6900 rows out of 46193
# Processed 7000 rows out of 46193
# Processed 7100 rows out of 46193
# Processed 7200 rows out of 46193
# Processed 7300 rows out of 46193
# Processed 7400 rows out of 46193
# Processed 7500 rows out of 46193
# Processed 7600 rows out of 46193
# Processed 7700 rows out of 46193
# Processed 7800 rows out of 46193
# Processed 7900 rows out of 46193
# Processed 8000 rows out of 46193
# Processed 8100 rows out of 46193
# Processed 8200 rows out of 46193
# Processed 8300 rows out of 46193
# Processed 8400 rows out of 46193
# Processed 8500 rows out of 46193
# Processed 8600 rows out of 46193
# Processed 8700 rows out of 46193
# Processed 8800 rows out of 46193
# Processed 8900 rows out of 46193
# Processed 9000 rows out of 46193
# Processed 9100 rows out of 46193
# Processed 9200 rows out of 46193
# Processed 9300 rows out of 46193
# Processed 9400 rows out of 46193
# Processed 9500 rows out of 46193
# Processed 9600 rows out of 46193
# Processed 9700 rows out of 46193
# Processed 9800 rows out of 46193
# Processed 9900 rows out of 46193
# Processed 10000 rows out of 46193
# Processed 10100 rows out of 46193
# Processed 10200 rows out of 46193
# Processed 10300 rows out of 46193
# Processed 10400 rows out of 46193
# Processed 10500 rows out of 46193
# Processed 10600 rows out of 46193
# Processed 10700 rows out of 46193
# Processed 10800 rows out of 46193
# Processed 10900 rows out of 46193
# Processed 11000 rows out of 46193
# Processed 11100 rows out of 46193
# Processed 11200 rows out of 46193
# Processed 11300 rows out of 46193
# Processed 11400 rows out of 46193
# Processed 11500 rows out of 46193
# Processed 11600 rows out of 46193
# Processed 11700 rows out of 46193
# Processed 11800 rows out of 46193
# Processed 11900 rows out of 46193
# Processed 12000 rows out of 46193
# Processed 12100 rows out of 46193
# Processed 12200 rows out of 46193
# Processed 12300 rows out of 46193
# Processed 12400 rows out of 46193
# Processed 12500 rows out of 46193
# Processed 12600 rows out of 46193
# Processed 12700 rows out of 46193
# Processed 12800 rows out of 46193
# Processed 12900 rows out of 46193
# Processed 13000 rows out of 46193
# Processed 13100 rows out of 46193
# Processed 13200 rows out of 46193
# Processed 13300 rows out of 46193
# Processed 13400 rows out of 46193
# Processed 13500 rows out of 46193
# Processed 13600 rows out of 46193
# Processed 13700 rows out of 46193
# Processed 13800 rows out of 46193
# Processed 13900 rows out of 46193
# Processed 14000 rows out of 46193
# Processed 14100 rows out of 46193
# Processed 14200 rows out of 46193
# Processed 14300 rows out of 46193
# Processed 14400 rows out of 46193
# Processed 14500 rows out of 46193
# Processed 14600 rows out of 46193
# Processed 14700 rows out of 46193
# Processed 14800 rows out of 46193
# Processed 14900 rows out of 46193
# Processed 15000 rows out of 46193
# Processed 15100 rows out of 46193
# Processed 15200 rows out of 46193
# Processed 15300 rows out of 46193
# Processed 15400 rows out of 46193
# Processed 15500 rows out of 46193
# Processed 15600 rows out of 46193
# Processed 15700 rows out of 46193
# Processed 15800 rows out of 46193
# Processed 15900 rows out of 46193
# Processed 16000 rows out of 46193
# Processed 16100 rows out of 46193
# Processed 16200 rows out of 46193
# Processed 16300 rows out of 46193
# Processed 16400 rows out of 46193
# Processed 16500 rows out of 46193
# Processed 16600 rows out of 46193
# Processed 16700 rows out of 46193
# Processed 16800 rows out of 46193
# Processed 16900 rows out of 46193
# Processed 17000 rows out of 46193
# Processed 17100 rows out of 46193
# Processed 17200 rows out of 46193
# Processed 17300 rows out of 46193
# Processed 17400 rows out of 46193
# Processed 17500 rows out of 46193
# Processed 17600 rows out of 46193
# Processed 17700 rows out of 46193
# Processed 17800 rows out of 46193
# Processed 17900 rows out of 46193
# Processed 18000 rows out of 46193
# Processed 18100 rows out of 46193
# Processed 18200 rows out of 46193
# Processed 18300 rows out of 46193
# Processed 18400 rows out of 46193
# Processed 18500 rows out of 46193
# Processed 18600 rows out of 46193
# Processed 18700 rows out of 46193
# Processed 18800 rows out of 46193
# Processed 18900 rows out of 46193
# Processed 19000 rows out of 46193
# Processed 19100 rows out of 46193
# Processed 19200 rows out of 46193
# Processed 19300 rows out of 46193
# Processed 19400 rows out of 46193
# Processed 19500 rows out of 46193
# Processed 19600 rows out of 46193
# Processed 19700 rows out of 46193
# Processed 19800 rows out of 46193
# Processed 19900 rows out of 46193
# Processed 20000 rows out of 46193
# Processed 20100 rows out of 46193
# Processed 20200 rows out of 46193
# Processed 20300 rows out of 46193
# Processed 20400 rows out of 46193
# Processed 20500 rows out of 46193
# Processed 20600 rows out of 46193
# Processed 20700 rows out of 46193
# Processed 20800 rows out of 46193
# Processed 20900 rows out of 46193
# Processed 21000 rows out of 46193
# Processed 21100 rows out of 46193
# Processed 21200 rows out of 46193
# Processed 21300 rows out of 46193
# Processed 21400 rows out of 46193
# Processed 21500 rows out of 46193
# Processed 21600 rows out of 46193
# Processed 21700 rows out of 46193
# Processed 21800 rows out of 46193
# Processed 21900 rows out of 46193
# Processed 22000 rows out of 46193
# Processed 22100 rows out of 46193
# Processed 22200 rows out of 46193
# Processed 22300 rows out of 46193
# Processed 22400 rows out of 46193
# Processed 22500 rows out of 46193
# Processed 22600 rows out of 46193
# Processed 22700 rows out of 46193
# Processed 22800 rows out of 46193
# Processed 22900 rows out of 46193
# Processed 23000 rows out of 46193
# Processed 23100 rows out of 46193
# Processed 23200 rows out of 46193
# Processed 23300 rows out of 46193
# Processed 23400 rows out of 46193
# Processed 23500 rows out of 46193
# Processed 23600 rows out of 46193
# Processed 23700 rows out of 46193
# Processed 23800 rows out of 46193
# Processed 23900 rows out of 46193
# Processed 24000 rows out of 46193
# Processed 24100 rows out of 46193
# Processed 24200 rows out of 46193
# Processed 24300 rows out of 46193
# Processed 24400 rows out of 46193
# Processed 24500 rows out of 46193
# Processed 24600 rows out of 46193
# Processed 24700 rows out of 46193
# Processed 24800 rows out of 46193
# Processed 24900 rows out of 46193
# Processed 25000 rows out of 46193
# Processed 25100 rows out of 46193
# Processed 25200 rows out of 46193
# Processed 25300 rows out of 46193
# Processed 25400 rows out of 46193
# Processed 25500 rows out of 46193
# Processed 25600 rows out of 46193
# Processed 25700 rows out of 46193
# Processed 25800 rows out of 46193
# Processed 25900 rows out of 46193
# Processed 26000 rows out of 46193
# Processed 26100 rows out of 46193
# Processed 26200 rows out of 46193
# Processed 26300 rows out of 46193
# Processed 26400 rows out of 46193
# Processed 26500 rows out of 46193
# Processed 26600 rows out of 46193
# Processed 26700 rows out of 46193
# Processed 26800 rows out of 46193
# Processed 26900 rows out of 46193
# Processed 27000 rows out of 46193
# Processed 27100 rows out of 46193
# Processed 27200 rows out of 46193
# Processed 27300 rows out of 46193
# Processed 27400 rows out of 46193
# Processed 27500 rows out of 46193
# Processed 27600 rows out of 46193
# Processed 27700 rows out of 46193
# Processed 27800 rows out of 46193
# Processed 27900 rows out of 46193
# Processed 28000 rows out of 46193
# Processed 28100 rows out of 46193
# Processed 28200 rows out of 46193
# Processed 28300 rows out of 46193
# Processed 28400 rows out of 46193
# Processed 28500 rows out of 46193
# Processed 28600 rows out of 46193
# Processed 28700 rows out of 46193
# Processed 28800 rows out of 46193
# Processed 28900 rows out of 46193
# Processed 29000 rows out of 46193
# Processed 29100 rows out of 46193
# Processed 29200 rows out of 46193
# Processed 29300 rows out of 46193
# Processed 29400 rows out of 46193
# Processed 29500 rows out of 46193
# Processed 29600 rows out of 46193
# Processed 29700 rows out of 46193
# Processed 29800 rows out of 46193
# Processed 29900 rows out of 46193
# Processed 30000 rows out of 46193
# Processed 30100 rows out of 46193
# Processed 30200 rows out of 46193
# Processed 30300 rows out of 46193
# Processed 30400 rows out of 46193
# Processed 30500 rows out of 46193
# Processed 30600 rows out of 46193
# Processed 30700 rows out of 46193
# Processed 30800 rows out of 46193
# Processed 30900 rows out of 46193
# Processed 31000 rows out of 46193
# Processed 31100 rows out of 46193
# Processed 31200 rows out of 46193
# Processed 31300 rows out of 46193
# Processed 31400 rows out of 46193
# Processed 31500 rows out of 46193
# Processed 31600 rows out of 46193
# Processed 31700 rows out of 46193
# Processed 31800 rows out of 46193
# Processed 31900 rows out of 46193
# Processed 32000 rows out of 46193
# Processed 32100 rows out of 46193
# Processed 32200 rows out of 46193
# Processed 32300 rows out of 46193
# Processed 32400 rows out of 46193
# Processed 32500 rows out of 46193
# Processed 32600 rows out of 46193
# Processed 32700 rows out of 46193
# Processed 32800 rows out of 46193
# Processed 32900 rows out of 46193
# Processed 33000 rows out of 46193
# Processed 33100 rows out of 46193
# Processed 33200 rows out of 46193
# Processed 33300 rows out of 46193
# Processed 33400 rows out of 46193
# Processed 33500 rows out of 46193
# Processed 33600 rows out of 46193
# Processed 33700 rows out of 46193
# Processed 33800 rows out of 46193
# Processed 33900 rows out of 46193
# Processed 34000 rows out of 46193
# Processed 34100 rows out of 46193
# Processed 34200 rows out of 46193
# Processed 34300 rows out of 46193
# Processed 34400 rows out of 46193
# Processed 34500 rows out of 46193
# Processed 34600 rows out of 46193
# Processed 34700 rows out of 46193
# Processed 34800 rows out of 46193
# Processed 34900 rows out of 46193
# Processed 35000 rows out of 46193
# Processed 35100 rows out of 46193
# Processed 35200 rows out of 46193
# Processed 35300 rows out of 46193
# Processed 35400 rows out of 46193
# Processed 35500 rows out of 46193
# Processed 35600 rows out of 46193
# Processed 35700 rows out of 46193
# Processed 35800 rows out of 46193
# Processed 35900 rows out of 46193
# Processed 36000 rows out of 46193
# Processed 36100 rows out of 46193
# Processed 36200 rows out of 46193
# Processed 36300 rows out of 46193
# Processed 36400 rows out of 46193
# Processed 36500 rows out of 46193
# Processed 36600 rows out of 46193
# Processed 36700 rows out of 46193
# Processed 36800 rows out of 46193
# Processed 36900 rows out of 46193
# Processed 37000 rows out of 46193
# Processed 37100 rows out of 46193
# Processed 37200 rows out of 46193
# Processed 37300 rows out of 46193
# Processed 37400 rows out of 46193
# Processed 37500 rows out of 46193
# Processed 37600 rows out of 46193
# Processed 37700 rows out of 46193
# Processed 37800 rows out of 46193
# Processed 37900 rows out of 46193
# Processed 38000 rows out of 46193
# Processed 38100 rows out of 46193
# Processed 38200 rows out of 46193
# Processed 38300 rows out of 46193
# Processed 38400 rows out of 46193
# Processed 38500 rows out of 46193
# Processed 38600 rows out of 46193
# Processed 38700 rows out of 46193
# Processed 38800 rows out of 46193
# Processed 38900 rows out of 46193
# Processed 39000 rows out of 46193
# Processed 39100 rows out of 46193
# Processed 39200 rows out of 46193
# Processed 39300 rows out of 46193
# Processed 39400 rows out of 46193
# Processed 39500 rows out of 46193
# Processed 39600 rows out of 46193
# Processed 39700 rows out of 46193
# Processed 39800 rows out of 46193
# Processed 39900 rows out of 46193
# Processed 40000 rows out of 46193
# Processed 40100 rows out of 46193
# Processed 40200 rows out of 46193
# Processed 40300 rows out of 46193
# Processed 40400 rows out of 46193
# Processed 40500 rows out of 46193
# Processed 40600 rows out of 46193
# Processed 40700 rows out of 46193
# Processed 40800 rows out of 46193
# Processed 40900 rows out of 46193
# Processed 41000 rows out of 46193
# Processed 41100 rows out of 46193
# Processed 41200 rows out of 46193
# Processed 41300 rows out of 46193
# Processed 41400 rows out of 46193
# Processed 41500 rows out of 46193
# Processed 41600 rows out of 46193
# Processed 41700 rows out of 46193
# Processed 41800 rows out of 46193
# Processed 41900 rows out of 46193
# Processed 42000 rows out of 46193
# Processed 42100 rows out of 46193
# Processed 42200 rows out of 46193
# Processed 42300 rows out of 46193
# Processed 42400 rows out of 46193
# Processed 42500 rows out of 46193
# Processed 42600 rows out of 46193
# Processed 42700 rows out of 46193
# Processed 42800 rows out of 46193
# Processed 42900 rows out of 46193
# Processed 43000 rows out of 46193
# Processed 43100 rows out of 46193
# Processed 43200 rows out of 46193
# Processed 43300 rows out of 46193
# Processed 43400 rows out of 46193
# Processed 43500 rows out of 46193
# Processed 43600 rows out of 46193
# Processed 43700 rows out of 46193
# Processed 43800 rows out of 46193
# Processed 43900 rows out of 46193
# Processed 44000 rows out of 46193
# Processed 44100 rows out of 46193
# Processed 44200 rows out of 46193
# Processed 44300 rows out of 46193
# Processed 44400 rows out of 46193
# Processed 44500 rows out of 46193
# Processed 44600 rows out of 46193
# Processed 44700 rows out of 46193
# Processed 44800 rows out of 46193
# Processed 44900 rows out of 46193
# Processed 45000 rows out of 46193
# Processed 45100 rows out of 46193
# Processed 45200 rows out of 46193
# Processed 45300 rows out of 46193
# Processed 45400 rows out of 46193
# Processed 45500 rows out of 46193
# Processed 45600 rows out of 46193
# Processed 45700 rows out of 46193
# Processed 45800 rows out of 46193
# Processed 45900 rows out of 46193
# Processed 46000 rows out of 46193
# Processed 46100 rows out of 46193
# Processed 46193 rows out of 46193

# %%
res = df.read("sentiment_results.csv")
